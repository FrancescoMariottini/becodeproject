# %% [markdown]
# Below block defines the function for getting a number of search results from immoweb.

# %%
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import random
from random import randint
import re

def get_search_results(maxpage):
    """Collect search results running up to the maxpage number of both newest 'house'  and 'appartment' sales,
    returning a nested dictionary of {'url':{'house_is':'0/1','info2':'',...}}"""
    # initialise the dictionary with the results
    search_results = {}
    # start the loop
    for i in range(1, maxpage+1):
        # for each loop, scrape one results page of houses and one of appartments
        # the results are added if they are not there yet
        for houselink in results_page_scrape(i,"house"):
            if houselink not in search_results:
                search_results[houselink] = {}
                search_results[houselink]["house_is"] = 1
        for apartmentlink in results_page_scrape(i,"apartment"):
            if apartmentlink not in search_results:
                search_results[apartmentlink] = {}
                search_results[apartmentlink]["house_is"] = 0
    return search_results

def results_page_scrape(pagenumber,propertytype):
    '''A subroutine scraping links from search results on a propertytype/page'''
    # initialise the return
    links = []
    # I slow down the frequency of requests to avoid being identified and therefore ban from the site
    time.sleep(random.uniform(1.0, 2.0))
    # setup the selenium webdriver; if able to find elements within the given
    # span it returns as soon as finding them, else it raises an exception after 10 seconds.
    driver = webdriver.Chrome()
    driver.implicitly_wait(10)
    url=f'https://www.immoweb.be/en/search/{propertytype}/for-sale?countries=BE&isALifeAnnuitySale=false&page={pagenumber}&orderBy=newest'
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html,'lxml')
    for elem in soup.find_all('a', attrs={"class":"card__title-link"}):
        # get hyperlink to property page
        hyperlink = elem.get('href')
        # cut the searchID off
        hyperlink = re.match("(.+)\?searchId=.+", hyperlink).group(1)
        # append to the return
        links.append(hyperlink)
    driver.close()
    return links

# %% [markdown]
# Getting 12K resuls would need to run this function up to max page number 200. That would take about 1 hour.
# Lets just do 2:

# %%
get_search_results(2)
# Out:
# {'https://www.immoweb.be/en/classified/house/for-sale/esneux/4130/8952912': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/brugge/8000/8952902': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/morlanwelz/7140/8952911': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/apartment-block/for-sale/eupen/4700/8952909': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/opwijk/1745/8952906': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/lixhe/4600/8952904': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/brasmenil/7604/8830685': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/jemappes/7012/8952891': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/kuurne/8520/8952890': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/tienen/3300/8952889': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/herstal/4040/8952887': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/la-calamine/4720/8952884': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/villa/for-sale/messancy/6780/8952876': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/bellecourt/7170/8952874': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/st-job-in-t-goor/2960/8952855': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/hensies/7350/8952866': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/merlemont/5600/8952865': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/mouscron/7700/8952863': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/anderlecht/1070/8952859': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/town-house/for-sale/soumagne/4630/8952836': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/st-lievens-houtem/9520/8952853': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/eupen/4700/8952852': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/brasschaat/2930/8952851': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/montroeul-au-bois/7911/8902281': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/bois-de-villers/5170/8952833': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/st-martens-latem/9830/8952808': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/villa/for-sale/naast/7062/8952826': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/deerlijk/8540/8952825': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/house/for-sale/knokke-heist/8300/8952821': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/mixed-use-building/for-sale/brugge/8380/8952820': {'house_is': 1},
#  'https://www.immoweb.be/en/classified/apartment/for-sale/antwerp-1/2018/8952905': {'house_is': 0},
#  'https://www.immoweb.be/en/classified/loft/for-sale/woluwe-saint-lambert/1200/8952903': {'house_is': 0},
#  'https://www.immoweb.be/en/classified/apartment/for-sale/ixelles/1050/8952883': {'house_is': 0},
#  'https://www.immoweb.be/en/classified/apartment/for-sale/laeken/1020/8952881': {'house_is': 0},
#  'https://www.immoweb.be/en/classified/apartment/for-sale/antwerpen/2000/8952862': {'house_is': 0},
#  'https://www.immoweb.be/en/classified/apartment/for-sale